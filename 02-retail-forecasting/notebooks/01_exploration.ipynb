# %% [markdown]
# # Title
#
# Short goal for this notebook.

# %%
import pandas as pd
from prophet import Prophet
import matplotlib.pyplot as plt

# Load processed data
df = pd.read_csv("../data/processed/retail_sales_processed.csv")

# Prophet requires specific column names
df = df.rename(columns={'date': 'ds', 'value': 'y'})

# Train the model
model = Prophet()
model.fit(df)

# Forecast 24 months ahead
future = model.make_future_dataframe(periods=24, freq='MS')
forecast = model.predict(future)

# Plot the forecast
fig1 = model.plot(forecast)
plt.title("Retail Sales Forecast")
plt.xlabel("Date")
plt.ylabel("Sales Value")
plt.show()
fig1.savefig("../visuals/retail_sales_forecast.png", dpi=300, bbox_inches="tight")
# Out:
# 00:21:49 - cmdstanpy - INFO - Chain [1] start processing
# 00:21:49 - cmdstanpy - INFO - Chain [1] done processing
